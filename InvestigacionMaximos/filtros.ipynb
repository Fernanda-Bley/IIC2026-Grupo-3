# %%
import pandas as pd

# %%
popu = pd.read_csv("./data/Population-Smokers.csv")
big_year = popu[popu["Year"] == 2010]
big_year.to_csv("./data/Population-Smokers-2010.csv", index=False)

# %%
big_year.sort_values(by="Population")
# Out:
#                              Entity Code  Year  \
# 758                           Nauru  NRU  2010
# 1080                         Tuvalu  TUV  2010
# 828                           Palau  PLW  2010
# 681                Marshall Islands  MHL  2010
# 23                          Andorra  AND  2010
# ...                             ...  ...   ...
# 450           High-income countries  NaN  2010
# 471                           India  IND  2010
# 219                           China  CHN  2010
# 1115  Upper-middle-income countries  NaN  2010
# 625   Lower-middle-income countries  NaN  2010
#
#       Prevalence of current tobacco use (% of adults)  Population
# 758                                         55.500000       10067
# 1080                                        41.800000       10635
# 828                                         21.400000       18418
# 681                                         28.400000       52065
# ...

# %%
smokers = pd.read_csv("./data/Daily-Smokers.csv")
verybig = smokers[smokers['Year'] == 1997]
verybig.to_csv("./data/Population-Smokers-1997.csv", index=False)
